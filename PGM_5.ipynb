# %% [markdown]
# <a href="https://colab.research.google.com/github/arathykrishnatr-creator/DS-Lab-Programs/blob/main/PGM_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

s = pd.Series([1, 3, 5, 6, 8])

print("Series:")
print(s)
# Out:
# Series:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
data = {
    "Country": ["Brazil", "Russia", "India", "China", "South Africa"],
    "Capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
    "Area": [8515767, 17098242, 3287263, 9596961, 1221037],
    "Population": [214, 144, 1428, 1412, 60]
}

df = pd.DataFrame(data, index=["BR", "RU", "IN", "CH", "SA"])

print("\nBRICS DataFrame:")
print(df)
# Out:
# BRICS DataFrame:
#          Country    Capital      Area  Population
# BR        Brazil   Brasilia   8515767         214
# RU        Russia     Moscow  17098242         144
# IN         India  New Delhi   3287263        1428
# CH         China    Beijing   9596961        1412
# SA  South Africa   Pretoria   1221037          60

# %%
cars = pd.read_csv("cars1.csv")
print("\nComplete Dataset:")
print(cars)
# Out:
# Complete Dataset:
#     mpg cylinders        displacement horsepower  weight  acceleration
# 0    18         8                 307        130  3504.0          12.0
# 1    15         8                 350        165  3693.0          11.5
# 2    18         8                 318        150  3436.0          11.0
# 3    16         8                 304        150  3433.0          12.0
# 4    17         8                 302        140  3449.0          10.5
# ..   ..       ...                 ...        ...     ...           ...
# 392  76         1       ford maverick        NaN     NaN           NaN
# 393  76         1          amc hornet        NaN     NaN           NaN
# 394  76         1  chevrolet chevette        NaN     NaN           NaN
# 395  76         1     chevrolet woody        NaN     NaN           NaN
# 396  76         2           vw rabbit        NaN     NaN           NaN
#
# [397 rows x 6 columns]

# %%
cars = pd.read_csv("cars1.csv")
print("\nFirst Four Records:")
print(cars.head(4))
# Out:
# First Four Records:
#   mpg cylinders displacement horsepower  weight  acceleration
# 0  18         8          307        130  3504.0          12.0
# 1  15         8          350        165  3693.0          11.5
# 2  18         8          318        150  3436.0          11.0
# 3  16         8          304        150  3433.0          12.0

# %%
cars = pd.read_csv("cars1.csv")
print("\nFifth and Sixth Records:")
print(cars.iloc[4:6])
# Out:
# Fifth and Sixth Records:
#   mpg cylinders displacement horsepower  weight  acceleration
# 4  17         8          302        140  3449.0          10.5
# 5  15         8          429        198  4341.0          10.0

# %%
cars = pd.read_csv("cars1.csv")
print("\nThird Row:")
print(cars.iloc[2])
# Out:
# Third Row:
# mpg                 18
# cylinders            8
# displacement       318
# horsepower         150
# weight          3436.0
# acceleration      11.0
# Name: 2, dtype: object

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Gender": ["Female", "Male", "Female", "Male"],
    "Age": [20, 22, 21, 23]
}
df = pd.DataFrame(data)
print("DataFrame:")
print(df)
# Out:
# DataFrame:
#       Name  Gender  Age
# 0  Aswathy  Female   20
# 1     John    Male   22
# 2    Meera  Female   21
# 3    Arjun    Male   23

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Gender": ["Female", "Male", "Female", "Male"],
    "Age": [20, 22, 21, 23]
}
df = pd.DataFrame(data)
print("\nFirst two rows:")
print(df[:2])
# Out:
# First two rows:
#       Name  Gender  Age
# 0  Aswathy  Female   20
# 1     John    Male   22

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Gender": ["Female", "Male", "Female", "Male"],
    "Age": [20, 22, 21, 23]
}
df = pd.DataFrame(data)
print("\nThird row onwards:")
print(df[2:])
# Out:
# Third row onwards:
#     Name  Gender  Age
# 2  Meera  Female   21
# 3  Arjun    Male   23

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.rand(4))
print("Complete Series:")
print(s)
# Out:
# Complete Series:
# 0    0.624410
# 1    0.126409
# 2    0.846138
# 3    0.625129
# dtype: float64

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.rand(4))
print("\nValues:")
print(s.values)
# Out:
# Values:
# [0.616318   0.61305893 0.05168561 0.14920391]

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.rand(4))
print("\nFirst two elements:")
print(s.head(2))
# Out:
# First two elements:
# 0    0.142210
# 1    0.426238
# dtype: float64

# %%
import pandas as pd
import numpy as np
s = pd.Series(np.random.rand(4))
print("\nLast three elements:")
print(s.tail(3))
# Out:
# Last three elements:
# 1    0.446896
# 2    0.575265
# 3    0.177235
# dtype: float64

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("DataFrame:")
print(df)
# Out:
# DataFrame:
#       Name  Age  Rating
# 0  Aswathy   20     4.5
# 1     John   22     4.0
# 2    Meera   21     4.8
# 3    Arjun   23     4.2

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nTranspose:")
print(df.T)
# Out:
# Transpose:
#               0     1      2      3
# Name    Aswathy  John  Meera  Arjun
# Age          20    22     21     23
# Rating      4.5   4.0    4.8    4.2

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nAxes:")
print(df.axes)
# Out:
# Axes:
# [RangeIndex(start=0, stop=4, step=1), Index(['Name', 'Age', 'Rating'], dtype='object')]

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Name       object
# Age         int64
# Rating    float64
# dtype: object

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nIs DataFrame Empty?")
print(df.empty)
# Out:
# Is DataFrame Empty?
# False

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nNumber of Dimensions:")
print(df.ndim)
# Out:
# Number of Dimensions:
# 2

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nShape:")
print(df.shape)
# Out:
# Shape:
# (4, 3)

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nTotal Number of Elements:")
print(df.size)
# Out:
# Total Number of Elements:
# 12

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nValues:")
print(df.values)
# Out:
# Values:
# [['Aswathy' 20 4.5]
#  ['John' 22 4.0]
#  ['Meera' 21 4.8]
#  ['Arjun' 23 4.2]]

# %%
import pandas as pd
data = {
    "Name": ["Aswathy", "John", "Meera", "Arjun"],
    "Age": [20, 22, 21, 23],
    "Rating": [4.5, 4.0, 4.8, 4.2]
}
df = pd.DataFrame(data)
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Name      0
# Age       0
# Rating    0
# dtype: int64
